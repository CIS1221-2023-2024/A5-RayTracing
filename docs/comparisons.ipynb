# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
results_480 = pd.DataFrame.from_dict([
    {"time" : 233, "peak_memory" : 13.29,"width" : 480, "ppm" : 59270, "samples" : 5,"depth" : 5, "workers" : 8},
    {"time" : 280, "peak_memory" : 11.46,"width" : 480, "ppm" : 59270, "samples" : 5,"depth" : 10, "workers" : 8},
    {"time" : 204, "peak_memory" : 11.45,"width" : 480, "ppm" : 67739, "samples" : 5,"depth" : 20, "workers" : 8},
    {"time" : 1461, "peak_memory" : 11.38,"width" : 480, "ppm" : 9457, "samples" : 20,"depth" : 5, "workers" : 8},
    {"time" : 2665, "peak_memory" : 11.49,"width" : 480, "ppm" : 5186, "samples" : 20,"depth" : 10, "workers" : 8},
    {"time" : 2945, "peak_memory" : 11.39,"width" : 480, "ppm" : 4693, "samples" : 20,"depth" : 20, "workers" : 8},
    {"time" : 2882, "peak_memory" : 11.39,"width" : 480, "ppm" : 4693, "samples" : 50,"depth" : 5, "workers" : 8},
    {"time" : 3500, "peak_memory" : 11.39,"width" : 480, "ppm" : 4693, "samples" : 50,"depth" : 10, "workers" : 8},
    {"time" : 4000, "peak_memory" : 11.39,"width" : 480, "ppm" : 4693, "samples" : 50,"depth" : 20, "workers" : 8},
])
results_1280 = pd.DataFrame.from_dict([
    {"time" : 7453, "peak_memory" : 71.20,"width" : 1280, "ppm" : 13180, "samples" : 5,"depth" : 5, "workers" : 8},
])

# %%
depths = [5,10,20]
fig, axs = plt.subplots(1, 3, figsize=(21, 7))
for idx,depth in enumerate(depths):
    depth_df = results_480[results_480["depth"] == depth]
    sns.barplot(depth_df, y="time", x="samples", ax=axs[idx]).set(title=f"Depth={depth}", xlabel="Samples", ylabel="Time (s)")
plt.show()

# %%
depths = [5,10,20]
fig, axs = plt.subplots(1, 3, figsize=(21, 7))
for idx,depth in enumerate(depths):
    depth_df = results_1280[results_1280["depth"] == depth]
    sns.barplot(depth_df, y="time", x="samples", ax=axs[idx]).set(title=f"Depth={depth}")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 5
#       3 for idx,depth in enumerate(depths):
#       4     depth_df = results_1280[results_1280["depth"] == depth]
# ----> 5     sns.barplot(depth_df, y="time", x="samples", ax=axs[idx]).set(title=f"Depth={depth}")
#       6 plt.show()
#
# File ~/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:2755, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2752 if estimator is len:
#    2753     estimator = "size"
# -> 2755 plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2756                       estimator, errorbar, n_boot, units, seed,
#    2757                       orient, color, palette, saturation,
#    2758                       width, errcolor, errwidth, capsize, dodge)
#    2760 if ax is None:
#    2761     ax = plt.gca()
#
# File ~/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:1532, in _BarPlotter.__init__(self, x, y, hue, data, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge)
#    1529 """Initialize the plotter."""
#    1530 self.establish_variables(x, y, hue, data, orient,
#    1531                          order, hue_order, units)
# -> 1532 self.establish_colors(color, palette, saturation)
#    1533 self.estimate_statistic(estimator, errorbar, n_boot, seed)
#    1535 self.dodge = dodge
#
# File ~/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:707, in _CategoricalPlotter.establish_colors(self, color, palette, saturation)
#     705 # Determine the gray color to use for the lines framing the plot
#     706 light_vals = [rgb_to_hls(*c)[1] for c in rgb_colors]
# --> 707 lum = min(light_vals) * .6
#     708 gray = mpl.colors.rgb2hex((lum, lum, lum))
#     710 # Assign object attributes
#
# ValueError: min() arg is an empty sequence
